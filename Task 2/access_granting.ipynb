# %%
# %sql
GRANT USE CATALOG ON CATALOG airbnb TO `shvahuliak.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airbnb TO `hnyp.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airbnb TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airbnb TO `strus.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airbnb TO `martsinkovska.pn@ucu.edu.ua`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA airbnb.raw TO `hnyp.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airbnb.raw.vol TO `hnyp.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA airbnb.raw TO `hashchuk.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airbnb.raw.vol TO `hashchuk.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA airbnb.raw TO `strus.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airbnb.raw.vol TO `strus.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA airbnb.raw TO `martsinkovska.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airbnb.raw.vol TO `martsinkovska.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airbnb.raw.listings TO `shvahuliak.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airbnb.raw.listings TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.listings TO `strus.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.listings TO `martsinkovska.pn@ucu.edu.ua`;
