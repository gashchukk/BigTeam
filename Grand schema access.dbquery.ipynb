-- %%
GRANT USE SCHEMA ON SCHEMA sandwich.bronze TO `shvahuliak.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.bronze TO `hnyp.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.bronze TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.bronze TO `strus.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.bronze TO `martsinkovska.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA sandwich.silver TO `shvahuliak.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.silver TO `hnyp.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.silver TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.silver TO `strus.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA sandwich.silver TO `martsinkovska.pn@ucu.edu.ua`;
