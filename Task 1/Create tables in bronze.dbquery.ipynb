-- %%
USE CATALOG sandwich;

CREATE TABLE bronze.customer AS SELECT * FROM samples.tpch.customer;

GRANT SELECT ON SCHEMA bronze TO `account users`;

CREATE TABLE bronze.lineitem AS SELECT * FROM samples.tpch.lineitem;
CREATE TABLE bronze.nation AS SELECT * FROM samples.tpch.nation;
CREATE TABLE bronze.orders AS SELECT * FROM samples.tpch.orders;
CREATE TABLE bronze.part AS SELECT * FROM samples.tpch.part;
CREATE TABLE bronze.partsupp AS SELECT * FROM samples.tpch.partsupp;
CREATE TABLE bronze.region AS SELECT * FROM samples.tpch.region;
CREATE TABLE bronze.supplier AS SELECT * FROM samples.tpch.supplier;
