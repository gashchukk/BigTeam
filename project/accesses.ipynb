# %%
# %sql
GRANT USE CATALOG ON CATALOG airport_delays TO `shvahuliak.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airport_delays TO `hnyp.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airport_delays TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airport_delays TO `strus.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG airport_delays TO `martsinkovska.pn@ucu.edu.ua`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA airport_delays.raw TO `hnyp.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airport_delays.raw.vol TO `hnyp.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA airport_delays.raw TO `hashchuk.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airport_delays.raw.vol TO `hashchuk.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA airport_delays.raw TO `shvahuliak.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airport_delays.raw.vol TO `strus.pn@ucu.edu.ua`;

GRANT USE SCHEMA ON SCHEMA airport_delays.raw TO `martsinkovska.pn@ucu.edu.ua`;
GRANT WRITE VOLUME ON VOLUME airport_delays.raw.vol TO `martsinkovska.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airport_delays.raw.apt_dly TO `shvahuliak.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.apt_dly TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.apt_dly TO `hnyp.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.apt_dly TO `martsinkovska.pn@ucu.edu.ua`;

GRANT SELECT ON TABLE airport_delays.raw.atc_pre_dep TO `shvahuliak.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.atc_pre_dep TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.atc_pre_dep TO `hnyp.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.atc_pre_dep TO `martsinkovska.pn@ucu.edu.ua`;

GRANT SELECT ON TABLE airport_delays.raw.enroute_dly TO `shvahuliak.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.enroute_dly TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.enroute_dly TO `hnyp.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airport_delays.raw.enroute_dly TO `martsinkovska.pn@ucu.edu.ua`;
