# %%
# %sql
GRANT SELECT ON TABLE airbnb.raw.london_listings TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.london_listings TO `strus.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.london_listings TO `martsinkovska.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.london_listings TO `hnyp.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airbnb.raw.tokyo_listings TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.tokyo_listings TO `strus.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.tokyo_listings TO `martsinkovska.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.raw.tokyo_listings TO `hnyp.pn@ucu.edu.ua`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA airbnb.silver TO `hnyp.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA airbnb.silver TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA airbnb.silver TO `strus.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA airbnb.silver TO `martsinkovska.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airbnb.silver.london_listings TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.silver.london_listings TO `strus.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.silver.london_listings TO `martsinkovska.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.silver.london_listings TO `hnyp.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airbnb.silver.tokyo_listings TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.silver.tokyo_listings TO `strus.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.silver.tokyo_listings TO `martsinkovska.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.silver.tokyo_listings TO `hnyp.pn@ucu.edu.ua`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA airbnb.gold TO `hnyp.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA airbnb.gold TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA airbnb.gold TO `strus.pn@ucu.edu.ua`;
GRANT USE SCHEMA ON SCHEMA airbnb.gold TO `martsinkovska.pn@ucu.edu.ua`;

# %%
# %sql
GRANT SELECT ON TABLE airbnb.gold.combined_listings TO `hashchuk.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.gold.combined_listings TO `strus.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.gold.combined_listings TO `martsinkovska.pn@ucu.edu.ua`;
GRANT SELECT ON TABLE airbnb.gold.combined_listings TO `hnyp.pn@ucu.edu.ua`;
