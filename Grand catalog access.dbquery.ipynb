-- %%
GRANT USE CATALOG ON CATALOG sandwich TO `shvahuliak.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG sandwich TO `hnyp.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG sandwich TO `hashchuk.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG sandwich TO `strus.pn@ucu.edu.ua`;
GRANT USE CATALOG ON CATALOG sandwich TO `martsinkovska.pn@ucu.edu.ua`;
